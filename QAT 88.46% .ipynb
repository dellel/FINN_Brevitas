# %%
# !pip install timm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /tmp/home_dir/.local/lib/python3.10/site-packages (1.0.14)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.14.1+cu116)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (1.13.1+cu116)
# Requirement already satisfied: safetensors in /tmp/home_dir/.local/lib/python3.10/site-packages (from timm) (0.5.2)
# Requirement already satisfied: huggingface_hub in /tmp/home_dir/.local/lib/python3.10/site-packages (from timm) (0.27.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.15.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.64.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /tmp/home_dir/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (10.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.7.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.7)

# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset, random_split
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.nn import CrossEntropyLoss
import timm
import brevitas.nn as qnn
from torchvision import transforms as T
from PIL import Image
from glob import glob
import random
import torch.nn as nn
import torch.nn.functional as F
from brevitas.core.quant import QuantType

# Set the seed for reproducibility
torch.manual_seed(2023)

# Define your paths
base_dir = os.environ['FINN_ROOT'] + "/notebooks/FINN_Brevitas/"
data_path = base_dir + "Dataset_BUSI_with_GT/"

# %%
from sklearn.model_selection import train_test_split

# %%
# Custom Dataset Class
class CustomDataset(Dataset):
    def __init__(self, root, transformations=None):
        self.transformations = transformations
        self.im_paths = []
        self.cls_names = {}
        
        # Load all images and infer class labels from folder names
        class_folders = sorted(glob(f"{root}/*"))  # e.g., Benign, Malignant, Normal
        print(f"Found class folders: {class_folders}")
        
        for idx, folder in enumerate(class_folders):
            class_name = os.path.basename(folder)  # e.g., "Benign"
            self.cls_names[class_name] = idx
            folder_images = glob(f"{folder}/*.png")
            print(f"Class '{class_name}' has {len(folder_images)} images.")
            self.im_paths.extend([(im_path, idx) for im_path in folder_images])
        
        self.im_paths.sort()  # Sort for reproducibility

    def __len__(self):
        return len(self.im_paths)
    
    def __getitem__(self, idx):
        im_path, label = self.im_paths[idx]
        im = Image.open(im_path).convert("L")  # Convert to grayscale
        if self.transformations:
            im = self.transformations(im)
        return im, label

# Subset class for splitting
class CustomDatasetSubset(Dataset):
    def __init__(self, parent_dataset, subset_paths, subset_labels):
        self.transformations = parent_dataset.transformations
        self.im_paths = list(zip(subset_paths, subset_labels))
    
    def __len__(self):
        return len(self.im_paths)
    
    def __getitem__(self, idx):
        im_path, label = self.im_paths[idx]
        im = Image.open(im_path).convert("L")  # Ensure grayscale conversion
        if self.transformations:
            im = self.transformations(im)
        return im, label

# Split dataset using stratified splitting
def split_dataset(dataset, train_ratio=0.8, val_ratio=0.1):
    # Get the image paths and labels
    paths, labels = zip(*dataset.im_paths)
    train_paths, temp_paths, train_labels, temp_labels = train_test_split(
        paths, labels, test_size=(1 - train_ratio), stratify=labels, random_state=2023
    )
    val_size = val_ratio / (1 - train_ratio)  # Adjust validation size relative to temp set
    val_paths, test_paths, val_labels, test_labels = train_test_split(
        temp_paths, temp_labels, test_size=(1 - val_size), stratify=temp_labels, random_state=2023
    )
    
    # Create datasets for each split
    train_ds = CustomDatasetSubset(dataset, train_paths, train_labels)
    val_ds = CustomDatasetSubset(dataset, val_paths, val_labels)
    test_ds = CustomDatasetSubset(dataset, test_paths, test_labels)
    
    return train_ds, val_ds, test_ds

# Dataloader Function
def get_dls(root, transformations, bs, ns=4):
    dataset = CustomDataset(root=root, transformations=transformations)
    train_ds, val_ds, test_ds = split_dataset(dataset)
    tr_dl = DataLoader(train_ds, batch_size=bs, shuffle=True, num_workers=4)
    val_dl = DataLoader(val_ds, batch_size=bs, shuffle=False, num_workers=4)
    ts_dl = DataLoader(test_ds, batch_size=1, shuffle=False, num_workers=ns)
    return tr_dl, val_dl, ts_dl, dataset.cls_names

# Root path for dataset
root = data_path
# Define advanced transformations with grayscale and augmentations
mean, std, im_size = [0.485], [0.229], 224
tfs = T.Compose([
    T.Resize((im_size, im_size)),
    T.RandomHorizontalFlip(),
    T.RandomRotation(20),
    T.RandomResizedCrop(im_size, scale=(0.8, 1.0)),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    T.RandomAffine(degrees=20, translate=(0.1, 0.1), shear=10),
    T.RandomGrayscale(p=1.0),  # Ensure images are converted to grayscale
    T.ToTensor(),
    T.RandomErasing(p=0.2),
    T.Normalize(mean=mean, std=std)
])

# Create DataLoaders
tr_dl, val_dl, ts_dl, classes = get_dls(root=root, transformations=tfs, bs=16)
print("Number of batches in training loader:", len(tr_dl))
print("Number of batches in validation loader:", len(val_dl))
print("Number of batches in test loader:", len(ts_dl))
print("Classes:", classes)
# Out:
# Found class folders: ['/home/administrateur/finn/notebooks/FINN_Brevitas/Dataset_BUSI_with_GT/Benign', '/home/administrateur/finn/notebooks/FINN_Brevitas/Dataset_BUSI_with_GT/Malignant', '/home/administrateur/finn/notebooks/FINN_Brevitas/Dataset_BUSI_with_GT/Normal']
# Class 'Benign' has 437 images.
# Class 'Malignant' has 210 images.
# Class 'Normal' has 133 images.
# Number of batches in training loader: 39
# Number of batches in validation loader: 5
# Number of batches in test loader: 78
# Classes: {'Benign': 0, 'Malignant': 1, 'Normal': 2}

# %%
# SEBlock and ResidualBlock Definitions
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Linear(channels, channels // reduction)
        self.act = nn.ReLU()
        self.fc2 = nn.Linear(channels // reduction, channels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        batch, channels, _, _ = x.size()
        y = self.global_pool(x).view(batch, channels)
        y = self.fc2(self.act(self.fc1(y))).view(batch, channels, 1, 1)
        y = self.sigmoid(y)
        return x * y

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, downsample=None, use_se=False):
        super(ResidualBlock, self).__init__()
        self.conv1 = qnn.QuantConv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, weight_bit_width=8, bias=False, quant_type=QuantType.INT)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.act1 = qnn.QuantReLU(bit_width=8, quant_type=QuantType.INT)
        self.conv2 = qnn.QuantConv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, weight_bit_width=8, bias=False, quant_type=QuantType.INT)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.downsample = downsample
        self.act2 = qnn.QuantReLU(bit_width=8, quant_type=QuantType.INT)
        self.use_se = use_se
        if use_se:
            self.se = SEBlock(out_channels)

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.act1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.use_se:
            out = self.se(out)
        out += identity
        out = self.act2(out)
        return out

# Model Definition
class AdvancedUltrasoundNet(nn.Module):
    def __init__(self, num_classes):
        super(AdvancedUltrasoundNet, self).__init__()
        self.conv1 = qnn.QuantConv2d(1, 64, kernel_size=7, stride=2, padding=3, weight_bit_width=8, bias=False, quant_type=QuantType.INT)
        self.bn1 = nn.BatchNorm2d(64)
        self.act1 = qnn.QuantReLU(bit_width=8, quant_type=QuantType.INT)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        # Residual Blocks with SE
        self.res1 = ResidualBlock(64, 64, use_se=True)
        self.res2 = ResidualBlock(64, 128, stride=2, downsample=self._downsample(64, 128), use_se=True)
        self.res3 = ResidualBlock(128, 256, stride=2, downsample=self._downsample(128, 256), use_se=True)
        self.res4 = ResidualBlock(256, 512, stride=2, downsample=self._downsample(256, 512), use_se=True)

        # Fully Connected Layers
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = qnn.QuantLinear(512, 256, bias=True, weight_bit_width=8, quant_type=QuantType.INT)
        self.act2 = qnn.QuantReLU(bit_width=8, quant_type=QuantType.INT)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = qnn.QuantLinear(256, 128, bias=True, weight_bit_width=8, quant_type=QuantType.INT)
        self.fc3 = qnn.QuantLinear(128, num_classes, bias=True, weight_bit_width=8, quant_type=QuantType.INT)

    def _downsample(self, in_channels, out_channels):
        return nn.Sequential(
            qnn.QuantConv2d(in_channels, out_channels, kernel_size=1, stride=2, weight_bit_width=8, bias=False, quant_type=QuantType.INT),
            nn.BatchNorm2d(out_channels)
        )

    def forward(self, x):
        x = self.pool1(self.act1(self.bn1(self.conv1(x))))
        x = self.res1(x)
        x = self.res2(x)
        x = self.res3(x)
        x = self.res4(x)
        x = self.global_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(self.act2(self.fc1(x)))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Initialize model, criterion, optimizer, and scheduler
model = AdvancedUltrasoundNet(num_classes=len(classes))

# %%
# Loss and optimizer
criterion = CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)  # Adjusted learning rate and weight decay
scheduler = CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-6)  # Adjusted Cosine Annealing with warm-up strategy
clip_value = 1.0  # Gradient clipping to stabilize training

# %%
# Training loop
def train_model(model, tr_dl, val_dl, criterion, optimizer, scheduler, epochs=200):
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in tr_dl:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        scheduler.step()

        print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(tr_dl):.4f}, Accuracy: {100 * correct/total:.2f}%")

        # Validation phase
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for inputs, labels in val_dl:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        print(f"Validation Loss: {val_loss/len(val_dl):.4f}, Validation Accuracy: {100 * correct_val/total_val:.2f}%")

# %%
# Train the model
train_model(model, tr_dl, val_dl, criterion, optimizer, scheduler, epochs=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1255: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at ../c10/core/TensorImpl.h:1758.)
#   return super(Tensor, self).rename(names)
# Epoch [1/200], Loss: 1.0451, Accuracy: 47.60%
# Validation Loss: 0.9786, Validation Accuracy: 56.41%
# Epoch [2/200], Loss: 0.9567, Accuracy: 57.21%
# Validation Loss: 0.9238, Validation Accuracy: 56.41%
# Epoch [3/200], Loss: 0.9221, Accuracy: 59.46%
# Validation Loss: 0.9045, Validation Accuracy: 58.97%
# Epoch [4/200], Loss: 0.9263, Accuracy: 60.58%
# Validation Loss: 0.8915, Validation Accuracy: 56.41%
# Epoch [5/200], Loss: 0.8897, Accuracy: 61.86%
# Validation Loss: 0.8615, Validation Accuracy: 64.10%
# Epoch [6/200], Loss: 0.8974, Accuracy: 58.97%
# Validation Loss: 0.8139, Validation Accuracy: 67.95%
# Epoch [7/200], Loss: 0.8494, Accuracy: 62.50%
# Validation Loss: 1.2871, Validation Accuracy: 55.13%
# Epoch [8/200], Loss: 0.8518, Accuracy: 61.06%
# Validation Loss: 0.7636, Validation Accuracy: 67.95%
# Epoch [9/200], Loss: 0.8320, Accuracy: 62.82%
# Validation Loss: 0.7741, Validation Accuracy: 67.95%
# Epoch [10/200], Loss: 0.8084, Accuracy: 65.87%
# Validation Loss: 0.7440, Validation Accuracy: 66.67%
# Epoch [11/200], Loss: 0.7949, Accuracy: 64.26%
# Validation Loss: 0.7256, Validation Accuracy: 71.79%
# Epoch [12/200], Loss: 0.7686, Accuracy: 65.38%
# Validation Loss: 0.7584, Validation Accuracy: 70.51%
# Epoch [13/200], Loss: 0.7768, Accuracy: 66.99%
# Validation Loss: 0.7955, Validation Accuracy: 64.10%
# Epoch [14/200], Loss: 0.7645, Accuracy: 67.47%
# Validation Loss: 0.8100, Validation Accuracy: 70.51%
# Epoch [15/200], Loss: 0.7530, Accuracy: 67.31%
# Validation Loss: 0.6739, Validation Accuracy: 71.79%
# Epoch [16/200], Loss: 0.7619, Accuracy: 66.67%
# Validation Loss: 0.6625, Validation Accuracy: 70.51%
# Epoch [17/200], Loss: 0.7294, Accuracy: 70.67%
# Validation Loss: 0.7793, Validation Accuracy: 60.26%
# Epoch [18/200], Loss: 0.7118, Accuracy: 69.71%
# Validation Loss: 0.8156, Validation Accuracy: 65.38%
# Epoch [19/200], Loss: 0.7299, Accuracy: 67.79%
# Validation Loss: 0.7263, Validation Accuracy: 64.10%
# Epoch [20/200], Loss: 0.6917, Accuracy: 70.83%
# Validation Loss: 0.6261, Validation Accuracy: 70.51%
# Epoch [21/200], Loss: 0.7208, Accuracy: 69.39%
# Validation Loss: 0.6849, Validation Accuracy: 70.51%
# Epoch [22/200], Loss: 0.6687, Accuracy: 72.44%
# Validation Loss: 0.6919, Validation Accuracy: 70.51%
# Epoch [23/200], Loss: 0.7001, Accuracy: 70.99%
# Validation Loss: 0.6701, Validation Accuracy: 73.08%
# Epoch [24/200], Loss: 0.7003, Accuracy: 71.15%
# Validation Loss: 0.7053, Validation Accuracy: 70.51%
# Epoch [25/200], Loss: 0.6719, Accuracy: 72.28%
# Validation Loss: 0.6011, Validation Accuracy: 71.79%
# Epoch [26/200], Loss: 0.6698, Accuracy: 71.47%
# Validation Loss: 0.7135, Validation Accuracy: 65.38%
# Epoch [27/200], Loss: 0.6411, Accuracy: 72.76%
# Validation Loss: 0.6319, Validation Accuracy: 71.79%
# Epoch [28/200], Loss: 0.6347, Accuracy: 73.88%
# Validation Loss: 0.6272, Validation Accuracy: 69.23%
# Epoch [29/200], Loss: 0.6731, Accuracy: 72.12%
# Validation Loss: 0.5949, Validation Accuracy: 73.08%
# Epoch [30/200], Loss: 0.6301, Accuracy: 74.84%
# Validation Loss: 0.6847, Validation Accuracy: 67.95%
# Epoch [31/200], Loss: 0.6590, Accuracy: 72.60%
# Validation Loss: 0.6422, Validation Accuracy: 65.38%
# Epoch [32/200], Loss: 0.6280, Accuracy: 74.04%
# Validation Loss: 0.6751, Validation Accuracy: 71.79%
# Epoch [33/200], Loss: 0.6035, Accuracy: 72.92%
# Validation Loss: 0.6448, Validation Accuracy: 74.36%
# Epoch [34/200], Loss: 0.6501, Accuracy: 73.40%
# Validation Loss: 0.6752, Validation Accuracy: 67.95%
# Epoch [35/200], Loss: 0.6178, Accuracy: 74.52%
# Validation Loss: 0.5816, Validation Accuracy: 73.08%
# Epoch [36/200], Loss: 0.6099, Accuracy: 74.36%
# Validation Loss: 0.7180, Validation Accuracy: 62.82%
# Epoch [37/200], Loss: 0.6179, Accuracy: 73.72%
# Validation Loss: 0.6470, Validation Accuracy: 71.79%
# Epoch [38/200], Loss: 0.5924, Accuracy: 76.60%
# Validation Loss: 0.6604, Validation Accuracy: 69.23%
# Epoch [39/200], Loss: 0.5936, Accuracy: 75.00%
# Validation Loss: 1.0785, Validation Accuracy: 58.97%
# Epoch [40/200], Loss: 0.6231, Accuracy: 75.16%
# Validation Loss: 0.6635, Validation Accuracy: 67.95%
# Epoch [41/200], Loss: 0.5983, Accuracy: 74.20%
# Validation Loss: 0.6039, Validation Accuracy: 74.36%
# Epoch [42/200], Loss: 0.5821, Accuracy: 77.72%
# Validation Loss: 0.6107, Validation Accuracy: 74.36%
# Epoch [43/200], Loss: 0.6246, Accuracy: 75.48%
# Validation Loss: 0.5983, Validation Accuracy: 73.08%
# Epoch [44/200], Loss: 0.5757, Accuracy: 76.28%
# Validation Loss: 0.7461, Validation Accuracy: 64.10%
# Epoch [45/200], Loss: 0.5906, Accuracy: 74.68%
# Validation Loss: 0.5959, Validation Accuracy: 70.51%
# Epoch [46/200], Loss: 0.5338, Accuracy: 79.81%
# Validation Loss: 0.6353, Validation Accuracy: 73.08%
# Epoch [47/200], Loss: 0.5323, Accuracy: 79.81%
# Validation Loss: 0.6523, Validation Accuracy: 67.95%
# Epoch [48/200], Loss: 0.5951, Accuracy: 75.64%
# Validation Loss: 0.7125, Validation Accuracy: 71.79%
# Epoch [49/200], Loss: 0.5932, Accuracy: 75.96%
# Validation Loss: 0.9037, Validation Accuracy: 65.38%
# Epoch [50/200], Loss: 0.5940, Accuracy: 75.00%
# Validation Loss: 0.6155, Validation Accuracy: 78.21%
# Epoch [51/200], Loss: 0.5386, Accuracy: 78.21%
# Validation Loss: 0.6165, Validation Accuracy: 71.79%
# Epoch [52/200], Loss: 0.5242, Accuracy: 79.49%
# Validation Loss: 0.6815, Validation Accuracy: 69.23%
# Epoch [53/200], Loss: 0.5228, Accuracy: 78.53%
# Validation Loss: 0.6703, Validation Accuracy: 67.95%
# Epoch [54/200], Loss: 0.5198, Accuracy: 78.04%
# Validation Loss: 0.4777, Validation Accuracy: 79.49%
# Epoch [55/200], Loss: 0.5284, Accuracy: 78.85%
# Validation Loss: 0.6705, Validation Accuracy: 73.08%
# Epoch [56/200], Loss: 0.5233, Accuracy: 79.17%
# Validation Loss: 0.7211, Validation Accuracy: 70.51%
# Epoch [57/200], Loss: 0.5162, Accuracy: 79.81%
# Validation Loss: 0.5910, Validation Accuracy: 74.36%
# Epoch [58/200], Loss: 0.4826, Accuracy: 81.41%
# Validation Loss: 0.7885, Validation Accuracy: 64.10%
# Epoch [59/200], Loss: 0.5533, Accuracy: 79.01%
# Validation Loss: 0.6385, Validation Accuracy: 67.95%
# Epoch [60/200], Loss: 0.4766, Accuracy: 81.09%
# Validation Loss: 0.6674, Validation Accuracy: 73.08%
# Epoch [61/200], Loss: 0.4800, Accuracy: 82.69%
# Validation Loss: 0.6465, Validation Accuracy: 67.95%
# Epoch [62/200], Loss: 0.5353, Accuracy: 78.85%
# Validation Loss: 0.6175, Validation Accuracy: 71.79%
# Epoch [63/200], Loss: 0.4829, Accuracy: 81.09%
# Validation Loss: 0.4304, Validation Accuracy: 87.18%
# Epoch [64/200], Loss: 0.4982, Accuracy: 80.13%
# Validation Loss: 0.6942, Validation Accuracy: 70.51%
# Epoch [65/200], Loss: 0.4631, Accuracy: 80.29%
# Validation Loss: 0.5285, Validation Accuracy: 78.21%
# Epoch [66/200], Loss: 0.4794, Accuracy: 81.89%
# Validation Loss: 0.4899, Validation Accuracy: 76.92%
# Epoch [67/200], Loss: 0.4766, Accuracy: 81.57%
# Validation Loss: 0.5799, Validation Accuracy: 74.36%
# Epoch [68/200], Loss: 0.4777, Accuracy: 81.09%
# Validation Loss: 0.5358, Validation Accuracy: 74.36%
# Epoch [69/200], Loss: 0.4743, Accuracy: 81.41%
# Validation Loss: 0.5953, Validation Accuracy: 82.05%
# Epoch [70/200], Loss: 0.5084, Accuracy: 79.65%
# Validation Loss: 0.4640, Validation Accuracy: 82.05%
# Epoch [71/200], Loss: 0.4549, Accuracy: 81.89%
# Validation Loss: 0.4043, Validation Accuracy: 80.77%
# Epoch [72/200], Loss: 0.4799, Accuracy: 80.13%
# Validation Loss: 0.8103, Validation Accuracy: 66.67%
# Epoch [73/200], Loss: 0.4453, Accuracy: 82.21%
# Validation Loss: 0.5690, Validation Accuracy: 74.36%
# Epoch [74/200], Loss: 0.4298, Accuracy: 82.53%
# Validation Loss: 0.5915, Validation Accuracy: 75.64%
# Epoch [75/200], Loss: 0.4935, Accuracy: 81.09%
# Validation Loss: 0.5983, Validation Accuracy: 73.08%
# Epoch [76/200], Loss: 0.4451, Accuracy: 81.73%
# Validation Loss: 0.5352, Validation Accuracy: 78.21%
# Epoch [77/200], Loss: 0.4590, Accuracy: 80.93%
# Validation Loss: 0.5745, Validation Accuracy: 76.92%
# Epoch [78/200], Loss: 0.4401, Accuracy: 82.21%
# Validation Loss: 0.6287, Validation Accuracy: 74.36%
# Epoch [79/200], Loss: 0.4534, Accuracy: 82.53%
# Validation Loss: 0.6784, Validation Accuracy: 69.23%
# Epoch [80/200], Loss: 0.4367, Accuracy: 84.46%
# Validation Loss: 0.7315, Validation Accuracy: 73.08%
# Epoch [81/200], Loss: 0.4236, Accuracy: 83.49%
# Validation Loss: 0.4841, Validation Accuracy: 79.49%
# Epoch [82/200], Loss: 0.4092, Accuracy: 83.97%
# Validation Loss: 0.6095, Validation Accuracy: 73.08%
# Epoch [83/200], Loss: 0.3760, Accuracy: 86.22%
# Validation Loss: 0.5887, Validation Accuracy: 79.49%
# Epoch [84/200], Loss: 0.4578, Accuracy: 81.73%
# Validation Loss: 0.7047, Validation Accuracy: 71.79%
# Epoch [85/200], Loss: 0.4158, Accuracy: 83.81%
# Validation Loss: 0.5847, Validation Accuracy: 70.51%
# Epoch [86/200], Loss: 0.3895, Accuracy: 83.17%
# Validation Loss: 0.5855, Validation Accuracy: 79.49%
# Epoch [87/200], Loss: 0.4098, Accuracy: 83.17%
# Validation Loss: 0.7168, Validation Accuracy: 71.79%
# Epoch [88/200], Loss: 0.4164, Accuracy: 82.85%
# Validation Loss: 0.7153, Validation Accuracy: 76.92%
# Epoch [89/200], Loss: 0.3977, Accuracy: 85.26%
# Validation Loss: 0.7128, Validation Accuracy: 70.51%
# Epoch [90/200], Loss: 0.4140, Accuracy: 83.49%
# Validation Loss: 0.6424, Validation Accuracy: 78.21%
# Epoch [91/200], Loss: 0.4222, Accuracy: 82.05%
# Validation Loss: 0.5428, Validation Accuracy: 74.36%
# Epoch [92/200], Loss: 0.3825, Accuracy: 84.94%
# Validation Loss: 0.5056, Validation Accuracy: 82.05%
# Epoch [93/200], Loss: 0.3463, Accuracy: 86.70%
# Validation Loss: 0.6138, Validation Accuracy: 74.36%
# Epoch [94/200], Loss: 0.3973, Accuracy: 85.10%
# Validation Loss: 0.6458, Validation Accuracy: 76.92%
# Epoch [95/200], Loss: 0.3818, Accuracy: 84.62%
# Validation Loss: 0.5460, Validation Accuracy: 78.21%
# Epoch [96/200], Loss: 0.4158, Accuracy: 84.29%
# Validation Loss: 0.4998, Validation Accuracy: 79.49%
# Epoch [97/200], Loss: 0.3889, Accuracy: 83.49%
# Validation Loss: 0.4233, Validation Accuracy: 83.33%
# Epoch [98/200], Loss: 0.3604, Accuracy: 85.26%
# Validation Loss: 0.5517, Validation Accuracy: 74.36%
# Epoch [99/200], Loss: 0.3593, Accuracy: 85.26%
# Validation Loss: 0.5694, Validation Accuracy: 75.64%
# Epoch [100/200], Loss: 0.3522, Accuracy: 86.22%
# Validation Loss: 0.6501, Validation Accuracy: 80.77%
# Epoch [101/200], Loss: 0.3603, Accuracy: 86.54%
# Validation Loss: 0.6716, Validation Accuracy: 78.21%
# Epoch [102/200], Loss: 0.3677, Accuracy: 85.42%
# Validation Loss: 0.4030, Validation Accuracy: 85.90%
# Epoch [103/200], Loss: 0.3327, Accuracy: 87.18%
# Validation Loss: 0.5767, Validation Accuracy: 76.92%
# Epoch [104/200], Loss: 0.3455, Accuracy: 86.70%
# Validation Loss: 0.6213, Validation Accuracy: 76.92%
# Epoch [105/200], Loss: 0.3847, Accuracy: 86.38%
# Validation Loss: 0.5388, Validation Accuracy: 78.21%
# Epoch [106/200], Loss: 0.3183, Accuracy: 87.66%
# Validation Loss: 0.5426, Validation Accuracy: 82.05%
# Epoch [107/200], Loss: 0.3384, Accuracy: 86.22%
# Validation Loss: 0.5955, Validation Accuracy: 75.64%
# Epoch [108/200], Loss: 0.3352, Accuracy: 87.50%
# Validation Loss: 0.4105, Validation Accuracy: 85.90%
# Epoch [109/200], Loss: 0.2940, Accuracy: 90.06%
# Validation Loss: 0.5579, Validation Accuracy: 78.21%
# Epoch [110/200], Loss: 0.3534, Accuracy: 86.86%
# Validation Loss: 0.4729, Validation Accuracy: 78.21%
# Epoch [111/200], Loss: 0.3377, Accuracy: 86.70%
# Validation Loss: 0.5493, Validation Accuracy: 82.05%
# Epoch [112/200], Loss: 0.3205, Accuracy: 88.78%
# Validation Loss: 0.4666, Validation Accuracy: 78.21%
# Epoch [113/200], Loss: 0.3402, Accuracy: 84.46%
# Validation Loss: 0.4818, Validation Accuracy: 78.21%
# Epoch [114/200], Loss: 0.3322, Accuracy: 87.66%
# Validation Loss: 0.5342, Validation Accuracy: 80.77%
# Epoch [115/200], Loss: 0.3165, Accuracy: 86.38%
# Validation Loss: 0.6851, Validation Accuracy: 75.64%
# Epoch [116/200], Loss: 0.3079, Accuracy: 87.18%
# Validation Loss: 0.5686, Validation Accuracy: 76.92%
# Epoch [117/200], Loss: 0.2771, Accuracy: 89.42%
# Validation Loss: 0.5788, Validation Accuracy: 78.21%
# Epoch [118/200], Loss: 0.2931, Accuracy: 88.46%
# Validation Loss: 0.7973, Validation Accuracy: 71.79%
# Epoch [119/200], Loss: 0.3057, Accuracy: 87.50%
# Validation Loss: 0.6297, Validation Accuracy: 75.64%
# Epoch [120/200], Loss: 0.3137, Accuracy: 87.82%
# Validation Loss: 0.5450, Validation Accuracy: 83.33%
# Epoch [121/200], Loss: 0.2834, Accuracy: 89.90%
# Validation Loss: 0.7297, Validation Accuracy: 76.92%
# Epoch [122/200], Loss: 0.2853, Accuracy: 89.74%
# Validation Loss: 0.4386, Validation Accuracy: 85.90%
# Epoch [123/200], Loss: 0.2833, Accuracy: 89.42%
# Validation Loss: 0.7352, Validation Accuracy: 78.21%
# Epoch [124/200], Loss: 0.3336, Accuracy: 87.82%
# Validation Loss: 0.4916, Validation Accuracy: 83.33%
# Epoch [125/200], Loss: 0.2565, Accuracy: 90.71%
# Validation Loss: 0.5656, Validation Accuracy: 79.49%
# Epoch [126/200], Loss: 0.2784, Accuracy: 88.78%
# Validation Loss: 0.6425, Validation Accuracy: 79.49%
# Epoch [127/200], Loss: 0.3162, Accuracy: 87.50%
# Validation Loss: 0.7206, Validation Accuracy: 70.51%
# Epoch [128/200], Loss: 0.2787, Accuracy: 88.62%
# Validation Loss: 0.3999, Validation Accuracy: 85.90%
# Epoch [129/200], Loss: 0.2413, Accuracy: 90.06%
# Validation Loss: 0.5943, Validation Accuracy: 80.77%
# Epoch [130/200], Loss: 0.2568, Accuracy: 90.22%
# Validation Loss: 0.6737, Validation Accuracy: 80.77%
# Epoch [131/200], Loss: 0.2357, Accuracy: 91.35%
# Validation Loss: 0.5732, Validation Accuracy: 82.05%
# Epoch [132/200], Loss: 0.2691, Accuracy: 88.94%
# Validation Loss: 0.4124, Validation Accuracy: 84.62%
# Epoch [133/200], Loss: 0.2980, Accuracy: 90.06%
# Validation Loss: 0.5095, Validation Accuracy: 80.77%
# Epoch [134/200], Loss: 0.2603, Accuracy: 89.58%
# Validation Loss: 0.6821, Validation Accuracy: 75.64%
# Epoch [135/200], Loss: 0.2747, Accuracy: 90.71%
# Validation Loss: 0.6009, Validation Accuracy: 75.64%
# Epoch [136/200], Loss: 0.2947, Accuracy: 87.02%
# Validation Loss: 0.5336, Validation Accuracy: 79.49%
# Epoch [137/200], Loss: 0.2267, Accuracy: 91.19%
# Validation Loss: 0.4592, Validation Accuracy: 80.77%
# Epoch [138/200], Loss: 0.2373, Accuracy: 91.19%
# Validation Loss: 0.6650, Validation Accuracy: 80.77%
# Epoch [139/200], Loss: 0.2305, Accuracy: 90.38%
# Validation Loss: 0.5814, Validation Accuracy: 76.92%
# Epoch [140/200], Loss: 0.2337, Accuracy: 91.03%
# Validation Loss: 0.6106, Validation Accuracy: 80.77%
# Epoch [141/200], Loss: 0.2514, Accuracy: 90.54%
# Validation Loss: 0.6388, Validation Accuracy: 80.77%
# Epoch [142/200], Loss: 0.2360, Accuracy: 90.87%
# Validation Loss: 0.7534, Validation Accuracy: 79.49%
# Epoch [143/200], Loss: 0.2201, Accuracy: 90.87%
# Validation Loss: 0.6562, Validation Accuracy: 78.21%
# Epoch [144/200], Loss: 0.2566, Accuracy: 90.38%
# Validation Loss: 0.5218, Validation Accuracy: 79.49%
# Epoch [145/200], Loss: 0.2463, Accuracy: 90.71%
# Validation Loss: 0.5850, Validation Accuracy: 79.49%
# Epoch [146/200], Loss: 0.2496, Accuracy: 89.90%
# Validation Loss: 0.5091, Validation Accuracy: 83.33%
# Epoch [147/200], Loss: 0.2094, Accuracy: 91.83%
# Validation Loss: 0.6240, Validation Accuracy: 78.21%
# Epoch [148/200], Loss: 0.2365, Accuracy: 90.87%
# Validation Loss: 0.5075, Validation Accuracy: 82.05%
# Epoch [149/200], Loss: 0.2117, Accuracy: 92.31%
# Validation Loss: 0.5634, Validation Accuracy: 79.49%
# Epoch [150/200], Loss: 0.2061, Accuracy: 91.99%
# Validation Loss: 0.5028, Validation Accuracy: 80.77%
# Epoch [151/200], Loss: 0.2342, Accuracy: 91.19%
# Validation Loss: 0.4854, Validation Accuracy: 83.33%
# Epoch [152/200], Loss: 0.2186, Accuracy: 92.31%
# Validation Loss: 0.4348, Validation Accuracy: 84.62%
# Epoch [153/200], Loss: 0.2099, Accuracy: 91.99%
# Validation Loss: 0.4943, Validation Accuracy: 80.77%
# Epoch [154/200], Loss: 0.2378, Accuracy: 90.87%
# Validation Loss: 0.5847, Validation Accuracy: 79.49%
# Epoch [155/200], Loss: 0.2123, Accuracy: 90.87%
# Validation Loss: 0.4293, Validation Accuracy: 84.62%
# Epoch [156/200], Loss: 0.2275, Accuracy: 91.67%
# Validation Loss: 0.5876, Validation Accuracy: 84.62%
# Epoch [157/200], Loss: 0.2299, Accuracy: 91.35%
# Validation Loss: 0.4915, Validation Accuracy: 79.49%
# Epoch [158/200], Loss: 0.2437, Accuracy: 90.71%
# Validation Loss: 0.6199, Validation Accuracy: 76.92%
# Epoch [159/200], Loss: 0.2168, Accuracy: 91.99%
# Validation Loss: 0.5672, Validation Accuracy: 76.92%
# Epoch [160/200], Loss: 0.2125, Accuracy: 92.79%
# Validation Loss: 0.5409, Validation Accuracy: 79.49%
# Epoch [161/200], Loss: 0.2012, Accuracy: 92.15%
# Validation Loss: 0.5654, Validation Accuracy: 82.05%
# Epoch [162/200], Loss: 0.1871, Accuracy: 92.63%
# Validation Loss: 0.5250, Validation Accuracy: 83.33%
# Epoch [163/200], Loss: 0.2150, Accuracy: 92.79%
# Validation Loss: 0.5456, Validation Accuracy: 84.62%
# Epoch [164/200], Loss: 0.2396, Accuracy: 90.54%
# Validation Loss: 0.5783, Validation Accuracy: 82.05%
# Epoch [165/200], Loss: 0.2142, Accuracy: 92.79%
# Validation Loss: 0.4790, Validation Accuracy: 82.05%
# Epoch [166/200], Loss: 0.2089, Accuracy: 93.11%
# Validation Loss: 0.7150, Validation Accuracy: 80.77%
# Epoch [167/200], Loss: 0.2171, Accuracy: 92.47%
# Validation Loss: 0.4711, Validation Accuracy: 82.05%
# Epoch [168/200], Loss: 0.2316, Accuracy: 91.35%
# Validation Loss: 0.5115, Validation Accuracy: 82.05%
# Epoch [169/200], Loss: 0.2261, Accuracy: 91.83%
# Validation Loss: 0.5340, Validation Accuracy: 82.05%
# Epoch [170/200], Loss: 0.1781, Accuracy: 93.27%
# Validation Loss: 0.5776, Validation Accuracy: 83.33%
# Epoch [171/200], Loss: 0.1799, Accuracy: 93.91%
# Validation Loss: 0.5557, Validation Accuracy: 83.33%
# Epoch [172/200], Loss: 0.1957, Accuracy: 93.11%
# Validation Loss: 0.5522, Validation Accuracy: 82.05%
# Epoch [173/200], Loss: 0.2152, Accuracy: 92.15%
# Validation Loss: 0.5004, Validation Accuracy: 83.33%
# Epoch [174/200], Loss: 0.2234, Accuracy: 91.51%
# Validation Loss: 0.3661, Validation Accuracy: 88.46%
# Epoch [175/200], Loss: 0.1869, Accuracy: 93.59%
# Validation Loss: 0.6514, Validation Accuracy: 84.62%
# Epoch [176/200], Loss: 0.1667, Accuracy: 94.23%
# Validation Loss: 0.4593, Validation Accuracy: 84.62%
# Epoch [177/200], Loss: 0.1867, Accuracy: 92.15%
# Validation Loss: 0.5232, Validation Accuracy: 80.77%
# Epoch [178/200], Loss: 0.1953, Accuracy: 91.99%
# Validation Loss: 0.5657, Validation Accuracy: 80.77%
# Epoch [179/200], Loss: 0.2196, Accuracy: 91.83%
# Validation Loss: 0.6758, Validation Accuracy: 79.49%
# Epoch [180/200], Loss: 0.1874, Accuracy: 92.79%
# Validation Loss: 0.6986, Validation Accuracy: 76.92%
# Epoch [181/200], Loss: 0.1577, Accuracy: 93.43%
# Validation Loss: 0.3691, Validation Accuracy: 82.05%
# Epoch [182/200], Loss: 0.1835, Accuracy: 92.15%
# Validation Loss: 0.6995, Validation Accuracy: 82.05%
# Epoch [183/200], Loss: 0.2339, Accuracy: 90.87%
# Validation Loss: 0.5614, Validation Accuracy: 82.05%
# Epoch [184/200], Loss: 0.1936, Accuracy: 92.95%
# Validation Loss: 0.5710, Validation Accuracy: 84.62%
# Epoch [185/200], Loss: 0.1960, Accuracy: 91.51%
# Validation Loss: 0.5032, Validation Accuracy: 80.77%
# Epoch [186/200], Loss: 0.2087, Accuracy: 91.51%
# Validation Loss: 0.7284, Validation Accuracy: 80.77%
# Epoch [187/200], Loss: 0.1902, Accuracy: 92.95%
# Validation Loss: 0.4232, Validation Accuracy: 85.90%
# Epoch [188/200], Loss: 0.1595, Accuracy: 94.87%
# Validation Loss: 0.5439, Validation Accuracy: 80.77%
# Epoch [189/200], Loss: 0.1985, Accuracy: 92.79%
# Validation Loss: 0.5387, Validation Accuracy: 84.62%
# Epoch [190/200], Loss: 0.1721, Accuracy: 92.95%
# Validation Loss: 0.5148, Validation Accuracy: 80.77%
# Epoch [191/200], Loss: 0.1641, Accuracy: 94.23%
# Validation Loss: 0.5506, Validation Accuracy: 80.77%
# Epoch [192/200], Loss: 0.2287, Accuracy: 91.51%
# Validation Loss: 0.4773, Validation Accuracy: 85.90%
# Epoch [193/200], Loss: 0.1858, Accuracy: 94.39%
# Validation Loss: 0.7374, Validation Accuracy: 78.21%
# Epoch [194/200], Loss: 0.1916, Accuracy: 92.31%
# Validation Loss: 0.4559, Validation Accuracy: 84.62%
# Epoch [195/200], Loss: 0.1759, Accuracy: 93.43%
# Validation Loss: 0.5389, Validation Accuracy: 83.33%
# Epoch [196/200], Loss: 0.1682, Accuracy: 93.43%
# Validation Loss: 0.5541, Validation Accuracy: 84.62%
# Epoch [197/200], Loss: 0.1748, Accuracy: 92.63%
# Validation Loss: 0.6098, Validation Accuracy: 82.05%
# Epoch [198/200], Loss: 0.2103, Accuracy: 91.83%
# Validation Loss: 0.4599, Validation Accuracy: 82.05%
# Epoch [199/200], Loss: 0.1911, Accuracy: 93.11%
# Validation Loss: 0.4774, Validation Accuracy: 83.33%
# Epoch [200/200], Loss: 0.2356, Accuracy: 90.87%
# Validation Loss: 0.5585, Validation Accuracy: 80.77%

# %%
# Save the trained model
torch.save(model.state_dict(), "dresquantized_cnn.pth")

# %%
# Evaluate on test set
model.eval()
correct_test = 0
total_test = 0
with torch.no_grad():
    for inputs, labels in ts_dl:
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

print(f"Test Accuracy: {100 * correct_test/total_test:.2f}%")
# Out:
# Test Accuracy: 88.46%
